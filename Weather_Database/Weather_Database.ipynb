# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime
# Import time module
import time
import csv

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 795

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b8826615961f019d3e0de6fdada4d584

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Narsaq"
city_weather = requests.get(city_url)
city_weather
city_weather.json()
# Out:
# {'coord': {'lon': -46.05, 'lat': 60.9167},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 37.4,
#   'feels_like': 8.85,
#   'temp_min': 37.4,
#   'temp_max': 37.4,
#   'pressure': 1012,
#   'humidity': 30},
#  'visibility': 10000,
#  'wind': {'speed': 40.29, 'deg': 70},
#  'clouds': {'all': 20},
#  'dt': 1612742217,
#  'sys': {'type': 1,
#   'id': 47,
#   'country': 'GL',
#   'sunrise': 1612696038,
#   'sunset': 1612726167},
#  'timezone': -10800,
#  'id': 3421719,
#  'name': 'Narsaq',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country" : city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
# Out:
# Processing Record 1 of Set 16 | nanortalik
# Processing Record 2 of Set 16 | tasiilaq
# Processing Record 3 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 16 | suzaka
# Processing Record 5 of Set 16 | lasa
# Processing Record 6 of Set 16 | cape town
# Processing Record 7 of Set 16 | chokurdakh
# Processing Record 8 of Set 16 | hilo
# Processing Record 9 of Set 16 | punta arenas
# Processing Record 10 of Set 16 | ushuaia
# Processing Record 11 of Set 16 | mataura
# Processing Record 12 of Set 16 | cockburn town
# Processing Record 13 of Set 16 | port elizabeth
# Processing Record 14 of Set 16 | castro
# Processing Record 15 of Set 16 | chara
# Processing Record 16 of Set 16 | barrow
# Processing Record 17 of Set 16 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 16 | maxixe
# Processing Record 19 of Set 16 | srednekolymsk
# Processing Record 20 of Set 16 | georgetown
# Processing Record 21 of Set 16 | san policarpo
# Processing Record 22 of Set 16 | huangzhou
# Processing Record 23 of Set 16 | mahajanga
# Processing Record 24 of Set 16 | rikitea
# Processing Record 25 of Set 16 | esperance
# Processing Record 26 of Set 16 | sioux lookout
# Processing Record 27 of Set 16 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 16 | puerto ayora
# Processing Record 29 of Set 16 | tuktoyaktuk
# Processing Record 30 of Set 16 | pascagoula
# Processing Record 31 of Set 16 | upernavik
# Processing Record 32 of Set 16 | arraial do cabo
# Processing Record 33 of Set 16 | port alfred
# Processing Record 34 of Set 16 | hobart
# Processing Record 35 of Set 16 | albany
# Processing Record 36 of Set 16 | broome
# Processing Record 37 of Set 16 | carnarvon
# Processing Record 38 of Set 16 | lebu
# Processing Record 39 of Set 16 | clyde river
# Processing Record 40 of Set 16 | ovre ardal
# Processing Record 41 of Set 16 | tawkar
# City not found. Skipping...
# Processing Record 42 of Set 16 | atasu
# Processing Record 43 of Set 16 | lavrentiya
# Processing Record 44 of Set 16 | codrington
# Processing Record 45 of Set 16 | cidreira
# Processing Record 46 of Set 16 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 47 of Set 16 | fort nelson
# Processing Record 48 of Set 16 | marystown
# Processing Record 49 of Set 16 | saldanha
# Processing Record 50 of Set 16 | mar del plata
# Processing Record 1 of Set 17 | thompson
# Processing Record 2 of Set 17 | wanning
# Processing Record 3 of Set 17 | hermanus
# Processing Record 4 of Set 17 | hithadhoo
# Processing Record 5 of Set 17 | salalah
# Processing Record 6 of Set 17 | busselton
# Processing Record 7 of Set 17 | boca do acre
# Processing Record 8 of Set 17 | dahuk
# Processing Record 9 of Set 17 | pringsewu
# Processing Record 10 of Set 17 | atuona
# Processing Record 11 of Set 17 | leningradskiy
# Processing Record 12 of Set 17 | ostersund
# Processing Record 13 of Set 17 | kismayo
# Processing Record 14 of Set 17 | sayansk
# Processing Record 15 of Set 17 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 17 | hambantota
# Processing Record 17 of Set 17 | la paz
# Processing Record 18 of Set 17 | yatou
# Processing Record 19 of Set 17 | bam
# Processing Record 20 of Set 17 | naantali
# Processing Record 21 of Set 17 | san patricio
# Processing Record 22 of Set 17 | saskylakh
# Processing Record 23 of Set 17 | cam pha
# City not found. Skipping...
# Processing Record 24 of Set 17 | ilulissat
# Processing Record 25 of Set 17 | kapaa
# Processing Record 26 of Set 17 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 17 | nantucket
# Processing Record 28 of Set 17 | kiunga
# Processing Record 29 of Set 17 | jumla
# Processing Record 30 of Set 17 | namatanai
# Processing Record 31 of Set 17 | qazanbulaq
# Processing Record 32 of Set 17 | nemuro
# Processing Record 33 of Set 17 | caravelas
# Processing Record 34 of Set 17 | qaanaaq
# Processing Record 35 of Set 17 | vilyuysk
# Processing Record 36 of Set 17 | tiksi
# Processing Record 37 of Set 17 | ouesso
# Processing Record 38 of Set 17 | paine
# Processing Record 39 of Set 17 | boden
# Processing Record 40 of Set 17 | labuhan
# Processing Record 41 of Set 17 | vila velha
# Processing Record 42 of Set 17 | asau
# Processing Record 43 of Set 17 | geraldton
# Processing Record 44 of Set 17 | maningrida
# Processing Record 45 of Set 17 | kracheh
# City not found. Skipping...
# Processing Record 46 of Set 17 | bethel
# Processing Record 47 of Set 17 | kaitangata
# Processing Record 48 of Set 17 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 17 | asfi
# Processing Record 50 of Set 17 | vardo
# Processing Record 1 of Set 18 | yinchuan
# Processing Record 2 of Set 18 | gobabis
# Processing Record 3 of Set 18 | yellowknife
# Processing Record 4 of Set 18 | khromtau
# Processing Record 5 of Set 18 | victoria
# Processing Record 6 of Set 18 | te anau
# Processing Record 7 of Set 18 | ancud
# Processing Record 8 of Set 18 | nikolskoye
# Processing Record 9 of Set 18 | at-bashi
# Processing Record 10 of Set 18 | new norfolk
# Processing Record 11 of Set 18 | libertador general san martin
# Processing Record 12 of Set 18 | palmer
# Processing Record 13 of Set 18 | ardakan
# Processing Record 14 of Set 18 | grindavik
# Processing Record 15 of Set 18 | mogadishu
# Processing Record 16 of Set 18 | pilot butte
# Processing Record 17 of Set 18 | sao domingos do prata
# Processing Record 18 of Set 18 | pisco
# Processing Record 19 of Set 18 | den helder
# Processing Record 20 of Set 18 | boa vista
# Processing Record 21 of Set 18 | puerto escondido
# Processing Record 22 of Set 18 | san rafael
# Processing Record 23 of Set 18 | touros
# Processing Record 24 of Set 18 | carutapera
# Processing Record 25 of Set 18 | pevek
# Processing Record 26 of Set 18 | avarua
# Processing Record 27 of Set 18 | bredasdorp
# Processing Record 28 of Set 18 | banepa
# Processing Record 29 of Set 18 | san nicolas
# Processing Record 30 of Set 18 | east london
# Processing Record 31 of Set 18 | teguldet
# Processing Record 32 of Set 18 | sulangan
# Processing Record 33 of Set 18 | airai
# Processing Record 34 of Set 18 | taoudenni
# Processing Record 35 of Set 18 | doka
# Processing Record 36 of Set 18 | bastia
# Processing Record 37 of Set 18 | luderitz
# Processing Record 38 of Set 18 | livingston
# Processing Record 39 of Set 18 | mackay
# Processing Record 40 of Set 18 | rajapur
# Processing Record 41 of Set 18 | humaita
# Processing Record 42 of Set 18 | richards bay
# Processing Record 43 of Set 18 | vaini
# Processing Record 44 of Set 18 | acapulco
# Processing Record 45 of Set 18 | bluff
# Processing Record 46 of Set 18 | bukene
# Processing Record 47 of Set 18 | jamestown
# Processing Record 48 of Set 18 | brae
# Processing Record 49 of Set 18 | constitucion
# Processing Record 50 of Set 18 | haimen
# Processing Record 1 of Set 19 | san cristobal
# Processing Record 2 of Set 19 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 19 | ixtapa
# Processing Record 4 of Set 19 | faanui
# Processing Record 5 of Set 19 | vestmannaeyjar
# Processing Record 6 of Set 19 | sinazongwe
# Processing Record 7 of Set 19 | coquimbo
# Processing Record 8 of Set 19 | kamenskoye
# City not found. Skipping...
# Processing Record 9 of Set 19 | sakakah
# Processing Record 10 of Set 19 | kilindoni
# Processing Record 11 of Set 19 | beloha
# Processing Record 12 of Set 19 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 19 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 19 | mareeba
# Processing Record 15 of Set 19 | gari
# Processing Record 16 of Set 19 | chunoyar
# Processing Record 17 of Set 19 | kattivakkam
# Processing Record 18 of Set 19 | mongomo
# Processing Record 19 of Set 19 | raudeberg
# Processing Record 20 of Set 19 | lagoa
# Processing Record 21 of Set 19 | ascension
# Processing Record 22 of Set 19 | japura
# Processing Record 23 of Set 19 | vostok
# Processing Record 24 of Set 19 | alofi
# Processing Record 25 of Set 19 | osypenko
# Processing Record 26 of Set 19 | barawe
# City not found. Skipping...
# Processing Record 27 of Set 19 | college
# Processing Record 28 of Set 19 | timra
# Processing Record 29 of Set 19 | ahipara
# Processing Record 30 of Set 19 | paucartambo
# City not found. Skipping...
# Processing Record 31 of Set 19 | petukhovo
# Processing Record 32 of Set 19 | porto santo
# Processing Record 33 of Set 19 | turkistan
# Processing Record 34 of Set 19 | puerto del rosario
# Processing Record 35 of Set 19 | port moresby
# Processing Record 36 of Set 19 | chuy
# Processing Record 37 of Set 19 | sorland
# Processing Record 38 of Set 19 | hamilton
# Processing Record 39 of Set 19 | kuminskiy
# Processing Record 40 of Set 19 | laurel
# Processing Record 41 of Set 19 | gornopravdinsk
# Processing Record 42 of Set 19 | bathsheba
# Processing Record 43 of Set 19 | novo aripuana
# Processing Record 44 of Set 19 | felidhoo
# City not found. Skipping...
# Processing Record 45 of Set 19 | saint-philippe
# Processing Record 46 of Set 19 | port hardy
# Processing Record 47 of Set 19 | gao
# Processing Record 48 of Set 19 | matara
# Processing Record 49 of Set 19 | husavik
# Processing Record 50 of Set 19 | flin flon
# Processing Record 1 of Set 20 | poso
# Processing Record 2 of Set 20 | jiuquan
# Processing Record 3 of Set 20 | yokaichi
# Processing Record 4 of Set 20 | navabad
# City not found. Skipping...
# Processing Record 5 of Set 20 | coahuayana
# Processing Record 6 of Set 20 | bambous virieux
# Processing Record 7 of Set 20 | bubaque
# Processing Record 8 of Set 20 | bandarbeyla
# Processing Record 9 of Set 20 | dikson
# Processing Record 10 of Set 20 | panambi
# Processing Record 11 of Set 20 | chagda
# City not found. Skipping...
# Processing Record 12 of Set 20 | sinnamary
# Processing Record 13 of Set 20 | maldonado
# Processing Record 14 of Set 20 | severo-kurilsk
# Processing Record 15 of Set 20 | cayenne
# Processing Record 16 of Set 20 | ransang
# Processing Record 17 of Set 20 | miri
# Processing Record 18 of Set 20 | inongo
# Processing Record 19 of Set 20 | kingman
# Processing Record 20 of Set 20 | batemans bay
# Processing Record 21 of Set 20 | polyarnyy
# Processing Record 22 of Set 20 | vincennes
# Processing Record 23 of Set 20 | saint-georges
# Processing Record 24 of Set 20 | ust-ilimsk
# Processing Record 25 of Set 20 | bengkulu
# Processing Record 26 of Set 20 | kamenka
# Processing Record 27 of Set 20 | baboua
# City not found. Skipping...
# Processing Record 28 of Set 20 | voh
# Processing Record 29 of Set 20 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 30 of Set 20 | zhezkazgan
# Processing Record 31 of Set 20 | lata
# Processing Record 32 of Set 20 | wulanhaote
# City not found. Skipping...
# Processing Record 33 of Set 20 | nicoya
# Processing Record 34 of Set 20 | nehe
# Processing Record 35 of Set 20 | qasigiannguit
# Processing Record 36 of Set 20 | port-gentil
# Processing Record 37 of Set 20 | prince rupert
# Processing Record 38 of Set 20 | burnie
# Processing Record 39 of Set 20 | port blair
# Processing Record 40 of Set 20 | butaritari
# Processing Record 41 of Set 20 | havre-saint-pierre
# Processing Record 42 of Set 20 | alyangula
# Processing Record 43 of Set 20 | okhotsk
# Processing Record 44 of Set 20 | norman wells
# Processing Record 45 of Set 20 | tapes
# Processing Record 46 of Set 20 | hualmay
# Processing Record 47 of Set 20 | provideniya
# Processing Record 48 of Set 20 | muriwai beach
# Processing Record 49 of Set 20 | torbay
# Processing Record 50 of Set 20 | eirunepe
# Processing Record 1 of Set 21 | tortoli
# Processing Record 2 of Set 21 | nakambala
# Processing Record 3 of Set 21 | oranjemund
# Processing Record 4 of Set 21 | klamath falls
# Processing Record 5 of Set 21 | kortkeros
# Processing Record 6 of Set 21 | george
# Processing Record 7 of Set 21 | inhambane
# Processing Record 8 of Set 21 | fernie
# Processing Record 9 of Set 21 | kahului
# Processing Record 10 of Set 21 | vila franca do campo
# Processing Record 11 of Set 21 | chapais
# Processing Record 12 of Set 21 | solovetskiy
# City not found. Skipping...
# Processing Record 13 of Set 21 | magadan
# Processing Record 14 of Set 21 | fortuna
# Processing Record 15 of Set 21 | cap-aux-meules
# Processing Record 16 of Set 21 | aklavik
# Processing Record 17 of Set 21 | vao
# Processing Record 18 of Set 21 | salvador
# Processing Record 19 of Set 21 | sarahan
# Processing Record 20 of Set 21 | la ronge
# Processing Record 21 of Set 21 | milkovo
# Processing Record 22 of Set 21 | khatanga
# Processing Record 23 of Set 21 | rio gallegos
# Processing Record 24 of Set 21 | cherskiy
# Processing Record 25 of Set 21 | shelburne
# Processing Record 26 of Set 21 | fresnillo
# Processing Record 27 of Set 21 | grand-santi
# Processing Record 28 of Set 21 | lompoc
# Processing Record 29 of Set 21 | petershagen
# Processing Record 30 of Set 21 | maniwaki
# Processing Record 31 of Set 21 | sistranda
# Processing Record 32 of Set 21 | puerto quijarro
# Processing Record 33 of Set 21 | zhangjiakou
# Processing Record 34 of Set 21 | ossora
# Processing Record 35 of Set 21 | harper
# Processing Record 36 of Set 21 | beatrice
# Processing Record 37 of Set 21 | aksu
# Processing Record 38 of Set 21 | wuchang
# Processing Record 39 of Set 21 | aasiaat
# Processing Record 40 of Set 21 | tabuk
# Processing Record 41 of Set 21 | mananara
# Processing Record 42 of Set 21 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 21 | ormara
# Processing Record 44 of Set 21 | mitu
# Processing Record 45 of Set 21 | gwembe
# Processing Record 46 of Set 21 | sur
# Processing Record 47 of Set 21 | rypefjord
# Processing Record 48 of Set 21 | tambacounda
# Processing Record 49 of Set 21 | chizhou
# Processing Record 50 of Set 21 | korla
# Processing Record 1 of Set 22 | pousat
# City not found. Skipping...
# Processing Record 2 of Set 22 | padang
# Processing Record 3 of Set 22 | isangel
# Processing Record 4 of Set 22 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 22 | ribeira grande
# Processing Record 6 of Set 22 | la romana
# Processing Record 7 of Set 22 | chegem
# Processing Record 8 of Set 22 | gariaband
# Processing Record 9 of Set 22 | ayan
# Processing Record 10 of Set 22 | tuatapere
# Processing Record 11 of Set 22 | emporia
# Processing Record 12 of Set 22 | ouango
# Processing Record 13 of Set 22 | krasnogorskoye
# Processing Record 14 of Set 22 | rawson
# Processing Record 15 of Set 22 | villablino
# Processing Record 16 of Set 22 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 22 | ygatimi
# Processing Record 18 of Set 22 | noumea
# Processing Record 19 of Set 22 | mahebourg
# Processing Record 20 of Set 22 | nkoteng
# Processing Record 21 of Set 22 | tucuman
# Processing Record 22 of Set 22 | price
# Processing Record 23 of Set 22 | sao joao da barra
# Processing Record 24 of Set 22 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 22 | badiraguato
# Processing Record 26 of Set 22 | grand gaube
# Processing Record 27 of Set 22 | vila
# Processing Record 28 of Set 22 | pangnirtung
# Processing Record 29 of Set 22 | surt
# Processing Record 30 of Set 22 | am timan
# Processing Record 31 of Set 22 | akdepe
# Processing Record 32 of Set 22 | viedma
# Processing Record 33 of Set 22 | comodoro rivadavia
# Processing Record 34 of Set 22 | mount gambier
# Processing Record 35 of Set 22 | klyuchi
# Processing Record 36 of Set 22 | duvan
# Processing Record 37 of Set 22 | arlit
# Processing Record 38 of Set 22 | almenara
# Processing Record 39 of Set 22 | talnakh
# Processing Record 40 of Set 22 | san jose
# Processing Record 41 of Set 22 | iqaluit
# Processing Record 42 of Set 22 | kijang
# Processing Record 43 of Set 22 | urumqi
# Processing Record 44 of Set 22 | filingue
# Processing Record 45 of Set 22 | bereda
# Processing Record 46 of Set 22 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 22 | buta
# Processing Record 48 of Set 22 | russell
# Processing Record 49 of Set 22 | kavieng
# Processing Record 50 of Set 22 | mesolongion
# City not found. Skipping...
# Processing Record 1 of Set 23 | mount isa
# Processing Record 2 of Set 23 | najran
# Processing Record 3 of Set 23 | ibra
# Processing Record 4 of Set 23 | jacmel
# Processing Record 5 of Set 23 | la libertad
# Processing Record 6 of Set 23 | diffa
# Processing Record 7 of Set 23 | kiboga
# Processing Record 8 of Set 23 | bolungarvik
# City not found. Skipping...
# Processing Record 9 of Set 23 | polunochnoye
# Processing Record 10 of Set 23 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 23 | narsaq
# Processing Record 12 of Set 23 | north bend
# Processing Record 13 of Set 23 | nanakuli
# Processing Record 14 of Set 23 | kodiak
# Processing Record 15 of Set 23 | hasaki
# Processing Record 16 of Set 23 | kawana waters
# City not found. Skipping...
# Processing Record 17 of Set 23 | eenhana
# Processing Record 18 of Set 23 | afmadu
# City not found. Skipping...
# Processing Record 19 of Set 23 | saraland
# Processing Record 20 of Set 23 | nchelenge
# Processing Record 21 of Set 23 | sinkat
# City not found. Skipping...
# Processing Record 22 of Set 23 | honolulu
# Processing Record 23 of Set 23 | tateyama
# Processing Record 24 of Set 23 | haibowan
# City not found. Skipping...
# Processing Record 25 of Set 23 | waddan
# Processing Record 26 of Set 23 | saint george
# Processing Record 27 of Set 23 | saint-denis
# Processing Record 28 of Set 23 | kavaratti
# Processing Record 29 of Set 23 | viligili
# City not found. Skipping...
# Processing Record 30 of Set 23 | nhulunbuy
# Processing Record 31 of Set 23 | ballina
# Processing Record 32 of Set 23 | mallapuram
# Processing Record 33 of Set 23 | zabol
# Processing Record 34 of Set 23 | alice springs
# Processing Record 35 of Set 23 | teguise
# Processing Record 36 of Set 23 | dunedin
# Processing Record 37 of Set 23 | shirokiy
# Processing Record 38 of Set 23 | aviles
# Processing Record 39 of Set 23 | santa cruz
# Processing Record 40 of Set 23 | waycross
# Processing Record 41 of Set 23 | taltal
# Processing Record 42 of Set 23 | akcaabat
# Processing Record 43 of Set 23 | darhan
# Processing Record 44 of Set 23 | adrar
# Processing Record 45 of Set 23 | hauterive
# Processing Record 46 of Set 23 | ucluelet
# Processing Record 47 of Set 23 | krasnokholm
# Processing Record 48 of Set 23 | souillac
# Processing Record 49 of Set 23 | westport
# Processing Record 50 of Set 23 | dutlwe
# Processing Record 1 of Set 24 | bafra
# Processing Record 2 of Set 24 | bowen
# Processing Record 3 of Set 24 | muhoroni
# Processing Record 4 of Set 24 | esmeraldas
# Processing Record 5 of Set 24 | vuktyl
# Processing Record 6 of Set 24 | banda aceh
# Processing Record 7 of Set 24 | jaumave
# Processing Record 8 of Set 24 | paamiut
# Processing Record 9 of Set 24 | batagay
# Processing Record 10 of Set 24 | aksarka
# Processing Record 11 of Set 24 | yicheng
# Processing Record 12 of Set 24 | carlsbad
# Processing Record 13 of Set 24 | inverell
# Processing Record 14 of Set 24 | guerrero negro
# Processing Record 15 of Set 24 | sawtell
# Processing Record 16 of Set 24 | dhadar
# Processing Record 17 of Set 24 | barreirinhas
# Processing Record 18 of Set 24 | kjollefjord
# Processing Record 19 of Set 24 | klaksvik
# Processing Record 20 of Set 24 | ciudad bolivar
# Processing Record 21 of Set 24 | rock hill
# Processing Record 22 of Set 24 | mayo
# Processing Record 23 of Set 24 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 24 of Set 24 | nigel
# Processing Record 25 of Set 24 | bandarban
# Processing Record 26 of Set 24 | cabrero
# Processing Record 27 of Set 24 | san quintin
# Processing Record 28 of Set 24 | baracoa
# Processing Record 29 of Set 24 | daru
# Processing Record 30 of Set 24 | sandwick
# Processing Record 31 of Set 24 | sataua
# City not found. Skipping...
# Processing Record 32 of Set 24 | munxar
# Processing Record 33 of Set 24 | tarko-sale
# Processing Record 34 of Set 24 | lalibela
# Processing Record 35 of Set 24 | hovd
# Processing Record 36 of Set 24 | durban
# Processing Record 37 of Set 24 | coihaique
# Processing Record 38 of Set 24 | lumphat
# Processing Record 39 of Set 24 | veraval
# Processing Record 40 of Set 24 | watertown
# Processing Record 41 of Set 24 | kainantu
# Processing Record 42 of Set 24 | malakal
# Processing Record 43 of Set 24 | namibe
# Processing Record 44 of Set 24 | cortez
# Processing Record 45 of Set 24 | sechura
# Processing Record 46 of Set 24 | chimoio
# Processing Record 47 of Set 24 | zonguldak
# Processing Record 48 of Set 24 | tsabong
# Processing Record 49 of Set 24 | todos santos
# Processing Record 50 of Set 24 | imbituva
# Processing Record 1 of Set 25 | tahe
# Processing Record 2 of Set 25 | barentu
# Processing Record 3 of Set 25 | kerema
# Processing Record 4 of Set 25 | gairo
# Processing Record 5 of Set 25 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 25 | pinheiro machado
# Processing Record 7 of Set 25 | agva
# City not found. Skipping...
# Processing Record 8 of Set 25 | ponta do sol
# Processing Record 9 of Set 25 | razole
# Processing Record 10 of Set 25 | khorramshahr
# Processing Record 11 of Set 25 | sola
# Processing Record 12 of Set 25 | purwodadi
# Processing Record 13 of Set 25 | bur gabo
# City not found. Skipping...
# Processing Record 14 of Set 25 | dibaya
# City not found. Skipping...
# Processing Record 15 of Set 25 | los llanos de aridane
# Processing Record 16 of Set 25 | kununurra
# Processing Record 17 of Set 25 | buraydah
# Processing Record 18 of Set 25 | fevralsk
# City not found. Skipping...
# Processing Record 19 of Set 25 | mount kisco
# Processing Record 20 of Set 25 | hobyo
# Processing Record 21 of Set 25 | porto novo
# Processing Record 22 of Set 25 | huarmey
# Processing Record 23 of Set 25 | muros
# Processing Record 24 of Set 25 | takoradi
# Processing Record 25 of Set 25 | hidrolandia
# Processing Record 26 of Set 25 | mineiros
# Processing Record 27 of Set 25 | nipawin
# Processing Record 28 of Set 25 | kenitra
# Processing Record 29 of Set 25 | atocha
# Processing Record 30 of Set 25 | port hedland
# Processing Record 31 of Set 25 | maniitsoq
# Processing Record 32 of Set 25 | denpasar
# Processing Record 33 of Set 25 | arari
# Processing Record 34 of Set 25 | banjar
# Processing Record 35 of Set 25 | deputatskiy
# Processing Record 36 of Set 25 | malpe
# Processing Record 37 of Set 25 | seoul
# Processing Record 38 of Set 25 | dashitou
# Processing Record 39 of Set 25 | kristinehamn
# Processing Record 40 of Set 25 | mitchell
# Processing Record 41 of Set 25 | sabang
# Processing Record 42 of Set 25 | waingapu
# Processing Record 43 of Set 25 | keshod
# Processing Record 44 of Set 25 | marcona
# City not found. Skipping...
# Processing Record 45 of Set 25 | faya
# Processing Record 46 of Set 25 | sao filipe
# Processing Record 47 of Set 25 | mazagao
# Processing Record 48 of Set 25 | sijunjung
# Processing Record 49 of Set 25 | manicore
# Processing Record 50 of Set 25 | saint combs
# City not found. Skipping...
# Processing Record 1 of Set 26 | bireun
# Processing Record 2 of Set 26 | khasan
# Processing Record 3 of Set 26 | lincoln
# Processing Record 4 of Set 26 | fianga
# City not found. Skipping...
# Processing Record 5 of Set 26 | tornio
# Processing Record 6 of Set 26 | gazni
# City not found. Skipping...
# Processing Record 7 of Set 26 | tuggurt
# City not found. Skipping...
# Processing Record 8 of Set 26 | tura
# Processing Record 9 of Set 26 | chiman
# Processing Record 10 of Set 26 | ajdabiya
# Processing Record 11 of Set 26 | zeya
# Processing Record 12 of Set 26 | chicama
# Processing Record 13 of Set 26 | port angeles
# Processing Record 14 of Set 26 | norrtalje
# Processing Record 15 of Set 26 | damietta
# Processing Record 16 of Set 26 | valparaiso
# Processing Record 17 of Set 26 | bandipur
# Processing Record 18 of Set 26 | sheregesh
# Processing Record 19 of Set 26 | ampanihy
# Processing Record 20 of Set 26 | shamary
# Processing Record 21 of Set 26 | mikhaylovka
# Processing Record 22 of Set 26 | corlu
# Processing Record 23 of Set 26 | yar-sale
# Processing Record 24 of Set 26 | karatuzskoye
# Processing Record 25 of Set 26 | saint-joseph
# Processing Record 26 of Set 26 | nkayi
# Processing Record 27 of Set 26 | krasnyy oktyabr
# Processing Record 28 of Set 26 | maghama
# City not found. Skipping...
# Processing Record 29 of Set 26 | labytnangi
# Processing Record 30 of Set 26 | bad langensalza
# Processing Record 31 of Set 26 | mailag
# Processing Record 32 of Set 26 | vanimo
# Processing Record 33 of Set 26 | marzuq
# Processing Record 34 of Set 26 | imbituba
# Processing Record 35 of Set 26 | mahibadhoo
# Processing Record 36 of Set 26 | nuevitas
# Processing Record 37 of Set 26 | louis trichardt
# Processing Record 38 of Set 26 | de aar
# Processing Record 39 of Set 26 | canutama
# Processing Record 40 of Set 26 | tabou
# Processing Record 41 of Set 26 | sosnovo-ozerskoye
# Processing Record 42 of Set 26 | asmara
# Processing Record 43 of Set 26 | tautira
# Processing Record 44 of Set 26 | cururupu
# Processing Record 45 of Set 26 | giera
# Processing Record 46 of Set 26 | half moon bay
# Processing Record 47 of Set 26 | udachnyy
# Processing Record 48 of Set 26 | ginda
# Processing Record 49 of Set 26 | cap malheureux
# Processing Record 50 of Set 26 | praya
# Processing Record 1 of Set 27 | manggar
# Processing Record 2 of Set 27 | carballo
# Processing Record 3 of Set 27 | taburi
# City not found. Skipping...
# Processing Record 4 of Set 27 | oskemen
# Processing Record 5 of Set 27 | fairbanks
# Processing Record 6 of Set 27 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 27 | katobu
# Processing Record 8 of Set 27 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 27 | vikhorevka
# Processing Record 10 of Set 27 | creston
# Processing Record 11 of Set 27 | yelizovo
# Processing Record 12 of Set 27 | marion
# Processing Record 13 of Set 27 | uyemskiy
# Processing Record 14 of Set 27 | makakilo city
# Processing Record 15 of Set 27 | burgeo
# Processing Record 16 of Set 27 | paraiso
# Processing Record 17 of Set 27 | sitka
# Processing Record 18 of Set 27 | chumikan
# Processing Record 19 of Set 27 | kruisfontein
# Processing Record 20 of Set 27 | codajas
# Processing Record 21 of Set 27 | shingu
# Processing Record 22 of Set 27 | burica
# City not found. Skipping...
# Processing Record 23 of Set 27 | kikwit
# Processing Record 24 of Set 27 | port lincoln
# Processing Record 25 of Set 27 | dadu
# Processing Record 26 of Set 27 | stabat
# Processing Record 27 of Set 27 | otradnoye
# Processing Record 28 of Set 27 | tomatlan
# Processing Record 29 of Set 27 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 30 of Set 27 | cuiluan
# Processing Record 31 of Set 27 | francisco sa
# Processing Record 32 of Set 27 | verkhnyaya toyma
# Processing Record 33 of Set 27 | lensk
# Processing Record 34 of Set 27 | juruti
# Processing Record 35 of Set 27 | tilichiki
# Processing Record 36 of Set 27 | kaoma
# Processing Record 37 of Set 27 | avera
# Processing Record 38 of Set 27 | rock springs
# Processing Record 39 of Set 27 | kaniv
# Processing Record 40 of Set 27 | saurimo
# Processing Record 41 of Set 27 | kindu
# Processing Record 42 of Set 27 | laguna
# Processing Record 43 of Set 27 | kargopol
# Processing Record 44 of Set 27 | mathathane
# Processing Record 45 of Set 27 | guangyuan
# Processing Record 46 of Set 27 | le port
# Processing Record 47 of Set 27 | dakar
# Processing Record 48 of Set 27 | taipei
# Processing Record 49 of Set 27 | abu zabad
# Processing Record 50 of Set 27 | balimo
# City not found. Skipping...
# Processing Record 1 of Set 28 | taksimo
# Processing Record 2 of Set 28 | the valley
# Processing Record 3 of Set 28 | agaro
# Processing Record 4 of Set 28 | dreznica
# Processing Record 5 of Set 28 | bajil
# Processing Record 6 of Set 28 | mudyuga
# City not found. Skipping...
# Processing Record 7 of Set 28 | hami
# Processing Record 8 of Set 28 | liverpool
# Processing Record 9 of Set 28 | bac lieu
# Processing Record 10 of Set 28 | jeremie
# Processing Record 11 of Set 28 | gushikawa
# Processing Record 12 of Set 28 | pemba
# Processing Record 13 of Set 28 | upata
# Processing Record 14 of Set 28 | kandiari
# Processing Record 15 of Set 28 | bud
# Processing Record 16 of Set 28 | chase
# Processing Record 17 of Set 28 | luwuk
# Processing Record 18 of Set 28 | colomi
# Processing Record 19 of Set 28 | ust-ishim
# Processing Record 20 of Set 28 | xacmaz
# Processing Record 21 of Set 28 | valdivia
# Processing Record 22 of Set 28 | zyryanovskiy
# City not found. Skipping...
# Processing Record 23 of Set 28 | santa maria
# Processing Record 24 of Set 28 | labrea
# Processing Record 25 of Set 28 | erzin
# Processing Record 26 of Set 28 | van
# Processing Record 27 of Set 28 | presidente olegario
# Processing Record 28 of Set 28 | bay city
# Processing Record 29 of Set 28 | goundi
# Processing Record 30 of Set 28 | nyurba
# Processing Record 31 of Set 28 | ambon
# Processing Record 32 of Set 28 | san andres
# Processing Record 33 of Set 28 | rzhev
# Processing Record 34 of Set 28 | rocha
# Processing Record 35 of Set 28 | launceston
# Processing Record 36 of Set 28 | balykshi
# Processing Record 37 of Set 28 | inderborskiy
# City not found. Skipping...
# Processing Record 38 of Set 28 | diamantino
# Processing Record 39 of Set 28 | innisfail
# Processing Record 40 of Set 28 | minna
# Processing Record 41 of Set 28 | atar
# Processing Record 42 of Set 28 | sikandra rao
# Processing Record 43 of Set 28 | fortuna foothills
# Processing Record 44 of Set 28 | arauca
# Processing Record 45 of Set 28 | warmbad
# Processing Record 46 of Set 28 | minden
# Processing Record 47 of Set 28 | wamba
# Processing Record 48 of Set 28 | casa nova
# Processing Record 49 of Set 28 | kabwe
# Processing Record 50 of Set 28 | petropavl
# Processing Record 1 of Set 29 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 29 | ashford
# Processing Record 3 of Set 29 | lodwar
# Processing Record 4 of Set 29 | rolim de moura
# City not found. Skipping...
# Processing Record 5 of Set 29 | yarada
# Processing Record 6 of Set 29 | ambulu
# Processing Record 7 of Set 29 | lodja
# Processing Record 8 of Set 29 | wanaka
# Processing Record 9 of Set 29 | road town
# Processing Record 10 of Set 29 | manta
# Processing Record 11 of Set 29 | dwarka
# Processing Record 12 of Set 29 | novochernorechenskiy
# Processing Record 13 of Set 29 | zemio
# Processing Record 14 of Set 29 | meadow lake
# Processing Record 15 of Set 29 | berlevag
# Processing Record 16 of Set 29 | trinidad
# Processing Record 17 of Set 29 | sisimiut
# Processing Record 18 of Set 29 | flinders
# Processing Record 19 of Set 29 | quelimane
# Processing Record 20 of Set 29 | ilukste
# Processing Record 21 of Set 29 | palana
# Processing Record 22 of Set 29 | walvis bay
# Processing Record 23 of Set 29 | san javier
# Processing Record 24 of Set 29 | lorengau
# Processing Record 25 of Set 29 | tignere
# Processing Record 26 of Set 29 | chifeng
# Processing Record 27 of Set 29 | mecca
# Processing Record 28 of Set 29 | morrope
# Processing Record 29 of Set 29 | necochea
# Processing Record 30 of Set 29 | houston
# Processing Record 31 of Set 29 | pasni
# Processing Record 32 of Set 29 | dudinka
# Processing Record 33 of Set 29 | zhigansk
# Processing Record 34 of Set 29 | matagami
# Processing Record 35 of Set 29 | octeville
# Processing Record 36 of Set 29 | victor harbor
# Processing Record 37 of Set 29 | mogzon
# Processing Record 38 of Set 29 | moron de la frontera
# Processing Record 39 of Set 29 | arcata
# Processing Record 40 of Set 29 | killybegs
# Processing Record 41 of Set 29 | luena
# Processing Record 42 of Set 29 | lufilufi
# Processing Record 43 of Set 29 | ban dung
# Processing Record 44 of Set 29 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 29 | linxia
# Processing Record 46 of Set 29 | seminole
# Processing Record 47 of Set 29 | longyearbyen
# Processing Record 48 of Set 29 | hvolsvollur
# Processing Record 49 of Set 29 | sterling
# Processing Record 50 of Set 29 | portree
# Processing Record 1 of Set 30 | nishihara
# Processing Record 2 of Set 30 | nueva italia
# Processing Record 3 of Set 30 | ostrovnoy
# Processing Record 4 of Set 30 | george town
# Processing Record 5 of Set 30 | searcy
# Processing Record 6 of Set 30 | mayumba
# Processing Record 7 of Set 30 | tarakan
# Processing Record 8 of Set 30 | raga
# Processing Record 9 of Set 30 | birao
# Processing Record 10 of Set 30 | saint-francois
# Processing Record 11 of Set 30 | aloleng
# Processing Record 12 of Set 30 | parati
# Processing Record 13 of Set 30 | sete
# Processing Record 14 of Set 30 | sao luis de montes belos
# Processing Record 15 of Set 30 | pacific grove
# Processing Record 16 of Set 30 | sarkand
# Processing Record 17 of Set 30 | krutinka
# Processing Record 18 of Set 30 | mahon
# Processing Record 19 of Set 30 | beira
# Processing Record 20 of Set 30 | korogwe
# City not found. Skipping...
# Processing Record 21 of Set 30 | zhangye
# Processing Record 22 of Set 30 | yeppoon
# Processing Record 23 of Set 30 | byurakan
# Processing Record 24 of Set 30 | bambanglipuro
# Processing Record 25 of Set 30 | riyadh
# Processing Record 26 of Set 30 | baykit
# Processing Record 27 of Set 30 | manokwari
# Processing Record 28 of Set 30 | laizhou
# Processing Record 29 of Set 30 | gejiu
# Processing Record 30 of Set 30 | kiama
# Processing Record 31 of Set 30 | portland
# Processing Record 32 of Set 30 | lengshuijiang
# Processing Record 33 of Set 30 | keshan
# City not found. Skipping...
# Processing Record 34 of Set 30 | cabo san lucas
# Processing Record 35 of Set 30 | algarrobo
# Processing Record 36 of Set 30 | pombia
# Processing Record 37 of Set 30 | koumac
# Processing Record 38 of Set 30 | tripoli
# Processing Record 39 of Set 30 | itarema
# Processing Record 40 of Set 30 | ilo
# Processing Record 41 of Set 30 | kieta
# Processing Record 42 of Set 30 | koungou
# Processing Record 43 of Set 30 | nouadhibou
# Processing Record 44 of Set 30 | mullaitivu
# City not found. Skipping...
# Processing Record 45 of Set 30 | sumbe
# Processing Record 46 of Set 30 | umm lajj
# Processing Record 47 of Set 30 | gat
# Processing Record 48 of Set 30 | oistins
# Processing Record 49 of Set 30 | samarai
# Processing Record 50 of Set 30 | manado
# Processing Record 1 of Set 31 | port keats
# Processing Record 2 of Set 31 | kyren
# Processing Record 3 of Set 31 | bilibino
# Processing Record 4 of Set 31 | perth
# Processing Record 5 of Set 31 | oyama
# Processing Record 6 of Set 31 | katsuura
# Processing Record 7 of Set 31 | akita
# Processing Record 8 of Set 31 | aran
# Processing Record 9 of Set 31 | ilinskiy
# Processing Record 10 of Set 31 | guelengdeng
# City not found. Skipping...
# Processing Record 11 of Set 31 | chamonix-mont-blanc
# Processing Record 12 of Set 31 | bela vista de goias
# Processing Record 13 of Set 31 | dzhusaly
# City not found. Skipping...
# Processing Record 14 of Set 31 | mount holly
# Processing Record 15 of Set 31 | dois corregos
# Processing Record 16 of Set 31 | lagos
# Processing Record 17 of Set 31 | kashi
# Processing Record 18 of Set 31 | saint-louis
# Processing Record 19 of Set 31 | vicuna
# Processing Record 20 of Set 31 | kindersley
# Processing Record 21 of Set 31 | camacha
# Processing Record 22 of Set 31 | marawi
# Processing Record 23 of Set 31 | neftcala
# Processing Record 24 of Set 31 | pimenta bueno
# Processing Record 25 of Set 31 | castlegar
# Processing Record 26 of Set 31 | artesia
# Processing Record 27 of Set 31 | majene
# Processing Record 28 of Set 31 | guantanamo
# Processing Record 29 of Set 31 | rio grande
# Processing Record 30 of Set 31 | issia
# Processing Record 31 of Set 31 | solnechnyy
# Processing Record 32 of Set 31 | buritis
# Processing Record 33 of Set 31 | phuket
# Processing Record 34 of Set 31 | englewood
# Processing Record 35 of Set 31 | xudat
# Processing Record 36 of Set 31 | anadyr
# Processing Record 37 of Set 31 | shizuishan
# Processing Record 38 of Set 31 | misratah
# Processing Record 39 of Set 31 | magdagachi
# Processing Record 40 of Set 31 | kirensk
# Processing Record 41 of Set 31 | komsomolskiy
# Processing Record 42 of Set 31 | maine-soroa
# Processing Record 43 of Set 31 | dolbeau
# City not found. Skipping...
# Processing Record 44 of Set 31 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 31 | gazanjyk

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Nanortalik      GL  60.1432  -45.2371     30.60        87          90
# 1      Tasiilaq      GL  65.6145  -37.6368     26.60        46           0
# 2        Suzaka      JP  36.6500  138.3167     30.99        71          94
# 3          Lasa      IT  46.6166   10.7002     39.00        93          90
# 4     Cape Town      ZA -33.9258   18.4232     66.20        68           0
# 5    Chokurdakh      RU  70.6333  147.9167    -17.70        88         100
# 6          Hilo      US  19.7297 -155.0900     82.40        47          20
# 7  Punta Arenas      CL -53.1500  -70.9167     69.80        28           0
# 8       Ushuaia      AR -54.8000  -68.3000     55.40        71          20
# 9       Mataura      NZ -46.1927  168.8643     71.76        44         100
#
#    Wind Speed Current Description
# 0       16.64     overcast clouds
# 1        9.22           clear sky
# 2        7.00          light snow
# 3        6.91          light snow
# 4       14.97           clear sky
# 5        7.94     overcast clouds
# 6       14.97          few clouds
# 7        6.91           clear sky
# 8        8.05          few clouds
# 9        3.18     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
